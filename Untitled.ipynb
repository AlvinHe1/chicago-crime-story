# %%
import pandas as pd
df = pd.read_csv("/Users/alvinhe/Desktop/Crimes.csv")

# Check shape
print(df.shape)

# Sample 60000 rows
df_sample = df.sample(n=60000, random_state=42)

# Save smaller file
df_sample.to_csv("chicago_crime_sample.csv", index=False)

print("Saved subset file.")
# Out:
# (8503583, 22)
# Saved subset file.
